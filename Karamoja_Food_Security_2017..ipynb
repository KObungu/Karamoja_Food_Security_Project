# %% [markdown]
# # 1.0 Karamoja Food Security Monitoring (2017) — Crop Yield & Population
#
# ## Background
# Karamoja is one of the most food-insecure regions in Uganda. Low crop productivity (drought, pests, disease) contributes to food insecurity.
#
# Dalberg Data Insights (DDI) produced model outputs for the 2017 crop season to estimate yields for the two main staple crops:
# - **Sorghum**
# - **Maize**
#
# ## Project Goal
# Build a first draft of an interactive visualization tool (mockup) to help an NGO:
# - View results on a **map**
# - Analyze results by **District** and **Sub-county**
# - Prioritize areas for intervention
#
# ## Data Sources
# - `Uganda_Karamoja_District_Crop_Yield_Population.csv`
# - `Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv`
#
# ## Key Metrics (from data)
# - POP (population)
# - Yields (Kg/Ha): S_Yield_Ha, M_Yield_Ha
# - Crop areas (Ha): Crop_Area_Ha, S_Area_Ha, M_Area_Ha
# - Total production (Kg): S_Prod_Tot, M_Prod_Tot

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %%
district_df = pd.read_csv("TABLES/Uganda_Karamoja_District_Crop_Yield_Population.csv")
subcounty_df = pd.read_csv("TABLES/Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv")

district_df.head(), subcounty_df.head()
# Out:
# (   OBJECTID     NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  \
#  0        92     ABIM   90385  2771977106         449        1040
#  1        96   AMUDAT  101790  1643582836         205        1297
#  2        20  KAABONG  627057  7373606003         279         945
#  3        85   KOTIDO  243157  3641539808         331        1148
#  4         5   MOROTO  127811  3570160948         128         355
#
#     Crop_Area_Ha     S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot
#  0   5470.068394   3277.295971  1848.621855     1471506     1922567
#  1   5765.443719   2973.423860  2733.661014      609552     3545558
#  2  28121.672530  20544.194960  7394.416334     5731830     6987723
#  3  53032.649450  50247.443900  1751.372284    16631904     2010575
#  4   5954.814048   4741.748776  1190.050606      606944      422468  ,
#     OBJECTID       SUBCOUNTY_NAME DISTRICT_NAME    POP        Area Karamoja  \
#  0       263              KACHERI        KOTIDO  17244  1067176155        Y
# ...
